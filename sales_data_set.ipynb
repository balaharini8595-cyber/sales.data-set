# %% [markdown]
# <a href="https://colab.research.google.com/github/balaharini8595-cyber/sales.data-set/blob/main/sales_data_set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path="/content/drive/MyDrive/Sales Dataset.csv"

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(file_path)

# %%
data.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-26776    9726    1275         5  Electronics  Electronic Games
# 1  B-26776    9726    1275         5  Electronics  Electronic Games
# 2  B-26776    9726    1275         5  Electronics  Electronic Games
# 3  B-26776    4975    1330        14  Electronics          Printers
# 4  B-26776    4975    1330        14  Electronics          Printers
#
#   PaymentMode  Order Date   CustomerName     State     City Year-Month
# 0         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 1         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12
# 2         UPI  2021-07-25   Robert Stone  New York  Buffalo    2021-07
# 3         UPI  2023-06-27  David Padilla   Florida    Miami    2023-06
# 4         UPI  2024-12-27  Connor Morgan  Illinois  Chicago    2024-12

# %%
import pandas as pd
import numpy as np

# Random data generate panna
np.random.seed(42)

data = {
    "Order_ID": np.arange(1001, 1021),
    "Product": np.random.choice(["Laptop", "Mobile", "Tablet", "Headphones"], 20),
    "Category": np.random.choice(["Electronics", "Accessories"], 20),
    "Quantity": np.random.randint(1, 5, 20),
    "Price_per_Unit": np.random.randint(500, 50000, 20),
    "Region": np.random.choice(["North", "South", "East", "West"], 20),
    "Order_Date": pd.date_range(start="2025-01-01", periods=20)
}

df = pd.DataFrame(data)

# Total Sales column create panrom
df["Total_Sales"] = df["Quantity"] * df["Price_per_Unit"]

print(df)

# CSV file aa save panna
df.to_csv("sales_dataset.csv", index=False)
# Out:
#     Order_ID     Product     Category  Quantity  Price_per_Unit Region  \
# 0       1001      Tablet  Accessories         3            4390  North
# 1       1002  Headphones  Electronics         3           42106   West
# 2       1003      Laptop  Accessories         2           31240  South
# 3       1004      Tablet  Accessories         4           15002   West
# 4       1005      Tablet  Accessories         4           22277   West
# 5       1006  Headphones  Accessories         4           11127  South
# 6       1007      Laptop  Accessories         4            9292  South
# 7       1008      Laptop  Accessories         3           43823  South
# 8       1009      Tablet  Accessories         2           43521  South
# 9       1010      Mobile  Accessories         2            8933  South
# 10      1011      Tablet  Electronics         3           43501   West
# 11      1012      Tablet  Electronics         2           11516  South
# ...
